# %%
import numpy as np
import matplotlib.pyplot as plt
import obspy 
from obspy import read

# %%
#%%time

st1=0
st2=0
st2 = read("./Idaho/*91*")
tr=st2 [0]
tr1=st2[1]
tr2=st2[2]
print()
print (tr.stats)
print()
print (tr1.stats)
print()
print (tr2.stats)
dt=st2[0].stats.starttime
print (dt)
print ("*********************")
#merging files
st1 = read("./Idaho/*92*")
tr=st1 [0]
tr1=st1[1]
tr2=st1[2]
print()
print (tr.stats)
print()
print (tr1.stats)
print()
print (tr2.stats)
st=st1+st2


st.write("./Idaho 6.5 BK81", format = "MSEED")


#create overview plot full length of file
st.plot(color='black',size=(1000,400),equal_scale=True)
# Out:
#          network: BK
#          station: BK81
#         location: 00
#          channel: HJ1
#        starttime: 2020-03-31T00:00:00.196300Z
#          endtime: 2020-04-01T00:00:00.236300Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 17280009
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 151580, 'encoding': 'INT32', 'byteorder': '>', 'record_length': 512, 'filesize': 77608960})
#
#          network: BK
#          station: BK81
#         location: 00
#          channel: HJ2
#        starttime: 2020-03-31T00:00:00.196300Z
#          endtime: 2020-04-01T00:00:00.236300Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 17280009
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 151580, 'encoding': 'INT32', 'byteorder': '>', 'record_length': 512, 'filesize': 77608960})
#
#          network: BK
#          station: BK81
#         location: 00
#          channel: HJ3
#        starttime: 2020-03-31T00:00:00.196300Z
#          endtime: 2020-04-01T00:00:00.236300Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 17280009
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 151580, 'encoding': 'INT32', 'byteorder': '>', 'record_length': 512, 'filesize': 77608960})
# 2020-03-31T00:00:00.196300Z
# *********************
#
#          network: BK
#          station: BK81
#         location: 00
#          channel: HJ1
#        starttime: 2020-04-01T00:00:00.241200Z
#          endtime: 2020-04-02T00:00:00.281200Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 17280009
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 151580, 'encoding': 'INT32', 'byteorder': '>', 'record_length': 512, 'filesize': 77608960})
#
#          network: BK
#          station: BK81
#         location: 00
#          channel: HJ2
#        starttime: 2020-04-01T00:00:00.241200Z
#          endtime: 2020-04-02T00:00:00.281200Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 17280009
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 151580, 'encoding': 'INT32', 'byteorder': '>', 'record_length': 512, 'filesize': 77608960})
#
#          network: BK
#          station: BK81
#         location: 00
#          channel: HJ3
#        starttime: 2020-04-01T00:00:00.241200Z
#          endtime: 2020-04-02T00:00:00.281200Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 17280009
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 151580, 'encoding': 'INT32', 'byteorder': '>', 'record_length': 512, 'filesize': 77608960})
